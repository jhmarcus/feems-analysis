# %% [markdown]
# # Imports

# %%
# base
import numpy as np
import pkg_resources
from sklearn.impute import SimpleImputer
from pandas_plink import read_plink
import math
import statsmodels.api as sm

# viz
import matplotlib.pyplot as plt
from matplotlib import gridspec
import cartopy.crs as ccrs

# feems
from feems.utils import prepare_graph_inputs
from feems import SpatialGraph, Viz
from feems.cross_validation import run_cv
from feems import Objective
from feems.objective import comp_mats
from node_param_ver import NodeParam_SpatialGraph

# change matplotlib fonts
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.sans-serif"] = "Arial"

# %% [markdown]
# # Data

# %%
data_path = "../../data/preprocessed/r1africa1nfb"

# read the genotype data and mean impute missing data
(bim, fam, G) = read_plink("{}/r1africa1nfb_no_popres".format(data_path))
imp = SimpleImputer(missing_values=np.nan, strategy="mean")
genotypes = imp.fit_transform((np.array(G)).T)

# setup graph
coord = np.loadtxt("{}/r1africa1nfb-run2_no_popres.coord".format(data_path))  # sample coordinates
grid = np.loadtxt("{}/r1africa1nfb-run2_no_popres.demes".format(data_path)) 
edges = np.loadtxt("{}/r1africa1nfb-run2_no_popres.edges".format(data_path))
outer = np.loadtxt("{}/r1africa1nfb-run2_no_popres.outer".format(data_path))

sp_graph = NodeParam_SpatialGraph(genotypes, coord, grid, edges, scale_snps=True)
# Out:
# Mapping files: 100%|██████████| 3/3 [00:00<00:00, 15.34it/s]

# %% [markdown]
# # Visualize

# %% [markdown]
# ## FEEMS fits

# %%
# %%time
# figure params
projection = ccrs.Mercator()
title_loc = "left"
title_pad = "-10"
title_fontsize = 12
edge_width = .5
edge_alpha = 1
edge_zorder = 3
obs_node_size = 5
obs_node_linewidth = .4
cbar_font_size = 8
cbar_ticklabelsize = 8
cbar_orientation = "horizontal"

# figure setup
fig = plt.figure(dpi=300)
spec = gridspec.GridSpec(ncols=2, nrows=1, figure=fig, wspace=0.0, hspace=0.0)

# axis 00 
ax_00 = fig.add_subplot(spec[0, 0], projection=projection)
ax_00.set_title("A", loc=title_loc, pad=title_pad, fontdict={"fontsize": title_fontsize})
lamb = 0.5
alpha = 0.05
sp_graph.fit(lamb=lamb, 
             alpha=alpha,
             lb=math.log(1e-6), 
             ub=math.log(1e+6))
v = Viz(ax_00, sp_graph, projection=projection, edge_width=edge_width, 
        edge_alpha=1, edge_zorder=100, sample_pt_size=20, 
        obs_node_size=obs_node_size, sample_pt_color="black", 
        cbar_font_size=10)
v.draw_map()
v.draw_edges(use_weights=True)
v.draw_obs_nodes(use_ids=False) 
# ax_00.text(.2, .85, "lambda={:.5f}".format(lamb), 
#            fontdict={"fontsize": 4}, transform = ax_00.transAxes)

# axis 01
ax_01 = fig.add_subplot(spec[0, 1], projection=projection)
ax_01.set_title("B", loc=title_loc, pad=title_pad, fontdict={"fontsize": title_fontsize})
lamb = 0.2
alpha = 0.02
sp_graph.fit_m(lamb=lamb, 
               alpha=alpha,
               lb=math.log(1e-6), 
               ub=math.log(1e+6))
v = Viz(ax_01, sp_graph, projection=projection, edge_width=edge_width, 
        edge_alpha=1, edge_zorder=100, sample_pt_size=20, 
        obs_node_size=obs_node_size, sample_pt_color="black", 
        cbar_font_size=10)
v.draw_map()
v.draw_edges(use_weights=True)
v.draw_obs_nodes(use_ids=False)
v.cbar_font_size = cbar_font_size
v.cbar_orientation = cbar_orientation
v.cbar_ticklabelsize = cbar_ticklabelsize
v.draw_edge_colorbar()
# Out:
# constant-w/variance fit, converged in 135 iterations, train_loss=-11334.9420421
# lambda=0.5000000, alpha=0.0500000, converged in 994 iterations, train_loss=-229597.5494248
# constant-w/variance fit, converged in 135 iterations, train_loss=-11334.9420421
# lambda=0.2000000, alpha=0.0200000, converged in 849 iterations, train_loss=-220003.1264045
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# CPU times: user 45.4 s, sys: 22.6 s, total: 1min 7s
# Wall time: 18.5 s
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
fig.savefig(
    "../../output/figures/supp-figure-15-mparam.pdf", bbox_inches="tight", pad_inches=.1
)

# %% [markdown]
# ## Goodness of fits

# %%
def cov_to_dist(S):
    s2 = np.diag(S).reshape(-1, 1)
    ones = np.ones((s2.shape[0], 1))
    D = s2 @ ones.T + ones @ s2.T - 2 * S
    return(D)

# %%
fig = plt.figure(constrained_layout=True, dpi=300, figsize=(6,3))
spec = gridspec.GridSpec(ncols=2, nrows=1, figure=fig)

# (A)
tril_idx = np.tril_indices(sp_graph.n_observed_nodes, k=-1)
ax_00 = fig.add_subplot(spec[0, 0])
ax_00.set_title("A", loc='left')

# fit feems while holding residual variance fixed
lamb = 0.5
alpha = 0.05
sp_graph.fit(lamb=lamb, 
             alpha=alpha,
             lb=math.log(1e-6), 
             ub=math.log(1e+6))
sp_graph.comp_graph_laplacian(sp_graph.w)

# create obj instance
obj = Objective(sp_graph)
fit_cov, _, emp_cov = comp_mats(obj)
fit_dist = cov_to_dist(fit_cov)[tril_idx]
emp_dist = cov_to_dist(emp_cov)[tril_idx]
X = sm.add_constant(fit_dist)
mod = sm.OLS(emp_dist, X)
res = mod.fit()
muhat, betahat = res.params
ax_00.scatter(fit_dist,
              emp_dist,
              marker=".", 
              alpha=1, 
              zorder=0, 
              color="black",
              s=3)

x_ = np.linspace(np.min(fit_dist), np.max(fit_dist), 20)
ax_00.plot(x_, muhat + betahat * x_, zorder=2, color="orange", linestyle='--', linewidth=1)
ax_00.text(2.2, 1, "R²={:.4f}".format(res.rsquared))
ax_00.set_xlabel("fitted distance")
ax_00.set_ylabel("genetic distance")


# (B)
tril_idx = np.tril_indices(sp_graph.n_observed_nodes, k=-1)
ax_01 = fig.add_subplot(spec[0, 1])
ax_01.set_title("B", loc='left')

# fit feems while holding residual variance fixed
lamb = 0.2
alpha = 0.02
sp_graph.fit_m(lamb=lamb, 
               alpha=alpha,
               lb=math.log(1e-6), 
               ub=math.log(1e+6))
sp_graph.comp_graph_laplacian(sp_graph.m)

# create obj instance
obj = Objective(sp_graph)
fit_cov, _, emp_cov = comp_mats(obj)
fit_dist = cov_to_dist(fit_cov)[tril_idx]
emp_dist = cov_to_dist(emp_cov)[tril_idx]
X = sm.add_constant(fit_dist)
mod = sm.OLS(emp_dist, X)
res = mod.fit()
muhat, betahat = res.params
ax_01.scatter(fit_dist,
              emp_dist,
              marker=".", 
              alpha=1, 
              zorder=0, 
              color="black",
              s=3)

x_ = np.linspace(np.min(fit_dist), np.max(fit_dist), 20)
ax_01.plot(x_, muhat + betahat * x_, zorder=2, color="orange", linestyle='--', linewidth=1)
ax_01.text(2.2, 1, "R²={:.4f}".format(res.rsquared))
ax_01.set_xlabel("fitted distance")
ax_01.set_ylabel("genetic distance")
# Out:
# constant-w/variance fit, converged in 135 iterations, train_loss=-11334.9420421
# lambda=0.5000000, alpha=0.0500000, converged in 994 iterations, train_loss=-229597.5494248
# constant-w/variance fit, converged in 135 iterations, train_loss=-11334.9420421
# lambda=0.2000000, alpha=0.0200000, converged in 849 iterations, train_loss=-220003.1264045
# Text(0, 0.5, 'genetic distance')

# %%
fig.savefig(
    "../../output/figures/supp-figure-16-mparam-gof.pdf", bbox_inches="tight", pad_inches=.1
)
